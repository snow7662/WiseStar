# %%
import sqlite3

# %%
conn = sqlite3.connect("output/question2solution")
cursor = conn.cursor()

# %%
cursor.execute("select * from text_mappings where text_hash = '1694ae14069a54fe485d4';")
row = cursor.fetchone()
row == None
# Out:
# True
